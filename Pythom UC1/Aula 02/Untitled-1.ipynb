# %% [markdown]
# 1. separar vasilha, pó , água, coador, suporte do coador, cafeteira, açucar
# 2. colocsr água na cafeteira, colocar o filtro, o pó, ligar a cafeteira, aguardar o café fiocar pronto.

# %% [markdown]
# #AULA 02

# %% [markdown]
# ## Exemplo de função
