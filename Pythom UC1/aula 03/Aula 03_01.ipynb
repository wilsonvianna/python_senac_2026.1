# %% [markdown]
# # Aula 03 - Variaveis

# %% [markdown]
# ## Ola mundo.

# %%
print("Olá, Mundo!!!!!")
# Out:
# Olá, Mundo!!!!!

# %% [markdown]
# ## Tipos de Variaveis

# %%
numero=15
numero_frac=15,2
texto="Papagaio"

# %%
type(numero)
type(numero_frac)
type(texto)
# Out:
# str

# %%
print(type(numero))
print(type(numero_frac))
print(type(texto))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
texto.upper()
# Out:
# 'PAPAGAIO'

# %%
numero+numero_frac
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 numero+numero_frac
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
numero+texto
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 numero+texto
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
texto*numero
# Out:
# 'PapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaioPapagaio'

# %%
texto2=texto+" "+texto
print(texto2)
# Out:
# Papagaio Papagaio

# %%
idade=input("Digite sua idade")

# %%
type(idade)
# Out:
# str

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplementedError if active frontend doesn't support stdin.

# %%
idade_num=int(idade)

# %%
idade_num=float(idade)

# %%
type(idade_num)
# Out:
# float

# %%
idade_num=int(input("Informa a sua idade"))

# %%
type(idade_num)
# Out:
# int
